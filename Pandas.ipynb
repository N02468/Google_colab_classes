# %% [markdown]
# <a href="https://colab.research.google.com/github/N02468/About_me/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World

# %%
x = 6
y = 7
print(x+y)

# This is a comment
# Out:
# 13

# %%
a = 45
b = 67
print(a-b)
print(a+b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
print(a**b)
# Out:
# -22
# 112
# 3015
# 0.6716417910447762
# 0
# 45
# 582422873843435732243403659008236909175319421543815500182225909081156108026977591407558065839111804962158203125

# %%
x = input("Type a number: ")
y = input("Type another number: ")

sum = int(x) + int(y)

print("The sum is: ", sum)
# Out:
# Type a number: 34
# Type another number: 5
# The sum is:  39

# %% [markdown]
# Import **Pandas**

# %%
import pandas as pd

# %%
dict1 = {
    "name":["Abdullah","Danish","Noman","Ibrahim","Umair"],
    "marks":[77,45,80,30,46],
    "city":["Karachi","Lahore","Islamabad","Peshawar","Quetta"],
    "country":["Pakistan","Pakistan","Pakistan","Pakistan","Pakistan"],
    "age":[20,21,22,23,2],
    "gender":["Male","Male","Male","Male","Male"],
    "status":["Single","Single","Single","Single","Single"],
    "degree":["BS","BS","BS","BS","BS"],
    "university":["FAST","FAST","FAST","FAST","FAST"],
}

df = pd.DataFrame(dict1)

# %%
df
# Out:
#        name  marks       city   country  age gender  status degree university
# 0  Abdullah     77    Karachi  Pakistan   20   Male  Single     BS       FAST
# 1    Danish     45     Lahore  Pakistan   21   Male  Single     BS       FAST
# 2     Noman     80  Islamabad  Pakistan   22   Male  Single     BS       FAST
# 3   Ibrahim     30   Peshawar  Pakistan   23   Male  Single     BS       FAST
# 4     Umair     46     Quetta  Pakistan    2   Male  Single     BS       FAST

# %%
df.head(2)
# Out:
#        name  marks     city   country  age gender  status degree university
# 0  Abdullah     77  Karachi  Pakistan   20   Male  Single     BS       FAST
# 1    Danish     45   Lahore  Pakistan   21   Male  Single     BS       FAST

# %%
df.tail(2)
# Out:
#       name  marks      city   country  age gender  status degree university
# 3  Ibrahim     30  Peshawar  Pakistan   23   Male  Single     BS       FAST
# 4    Umair     46    Quetta  Pakistan    2   Male  Single     BS       FAST

# %%
df.describe()
# Out:
#            marks        age
# count   5.000000   5.000000
# mean   55.600000  17.600000
# std    21.870071   8.792042
# min    30.000000   2.000000
# 25%    45.000000  20.000000
# 50%    46.000000  21.000000
# 75%    77.000000  22.000000
# max    80.000000  23.000000

# %%
df.drop("name",axis=1)
# Out:
#    marks       city   country  age gender  status degree university
# 0     77    Karachi  Pakistan   20   Male  Single     BS       FAST
# 1     45     Lahore  Pakistan   21   Male  Single     BS       FAST
# 2     80  Islamabad  Pakistan   22   Male  Single     BS       FAST
# 3     30   Peshawar  Pakistan   23   Male  Single     BS       FAST
# 4     46     Quetta  Pakistan    2   Male  Single     BS       FAST

# %%
df.drop(columns=["name"],inplace=True)

# %%
df
# Out:
#    marks       city   country  age gender  status degree university
# 0     77    Karachi  Pakistan   20   Male  Single     BS       FAST
# 1     45     Lahore  Pakistan   21   Male  Single     BS       FAST
# 2     80  Islamabad  Pakistan   22   Male  Single     BS       FAST
# 3     30   Peshawar  Pakistan   23   Male  Single     BS       FAST
# 4     46     Quetta  Pakistan    2   Male  Single     BS       FAST

# %%
df.drop(axis=0,columns=["age"])
# Out:
#    marks       city   country gender  status degree university
# 0     77    Karachi  Pakistan   Male  Single     BS       FAST
# 1     45     Lahore  Pakistan   Male  Single     BS       FAST
# 2     80  Islamabad  Pakistan   Male  Single     BS       FAST
# 3     30   Peshawar  Pakistan   Male  Single     BS       FAST
# 4     46     Quetta  Pakistan   Male  Single     BS       FAST

# %%
df
# Out:
#    marks       city   country  age gender  status degree university
# 0     77    Karachi  Pakistan   20   Male  Single     BS       FAST
# 1     45     Lahore  Pakistan   21   Male  Single     BS       FAST
# 2     80  Islamabad  Pakistan   22   Male  Single     BS       FAST
# 3     30   Peshawar  Pakistan   23   Male  Single     BS       FAST
# 4     46     Quetta  Pakistan    2   Male  Single     BS       FAST

# %%
df.drop(2,axis=0)
# Out:
#    marks      city   country  age gender  status degree university
# 0     77   Karachi  Pakistan   20   Male  Single     BS       FAST
# 1     45    Lahore  Pakistan   21   Male  Single     BS       FAST
# 3     30  Peshawar  Pakistan   23   Male  Single     BS       FAST
# 4     46    Quetta  Pakistan    2   Male  Single     BS       FAST

# %%
df
# Out:
#    marks       city   country  age gender  status degree university
# 0     77    Karachi  Pakistan   20   Male  Single     BS       FAST
# 1     45     Lahore  Pakistan   21   Male  Single     BS       FAST
# 2     80  Islamabad  Pakistan   22   Male  Single     BS       FAST
# 3     30   Peshawar  Pakistan   23   Male  Single     BS       FAST
# 4     46     Quetta  Pakistan    2   Male  Single     BS       FAST

# %%
df["names"]= ["Abdullah","Danish","Noman","Ibrahim","Umair"]

# %%
df
# Out:
#    marks       city   country  age gender  status degree university     names
# 0     77    Karachi  Pakistan   20   Male  Single     BS       FAST  Abdullah
# 1     45     Lahore  Pakistan   21   Male  Single     BS       FAST    Danish
# 2     80  Islamabad  Pakistan   22   Male  Single     BS       FAST     Noman
# 3     30   Peshawar  Pakistan   23   Male  Single     BS       FAST   Ibrahim
# 4     46     Quetta  Pakistan    2   Male  Single     BS       FAST     Umair

# %%
df.to_csv("friends.csv")

# %%
df = pd.read_excel('mashhod.xlsx')

# %%
df
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0          NaN         NaN         NaN         NaN         NaN         NaN
# 1          NaN         NaN         NaN         NaN         NaN         NaN
# 2          NaN         NaN         NaN         NaN         NaN         NaN
# 3          NaN         NaN         NaN         NaN         NaN         NaN
# 4          NaN         NaN         NaN         NaN         NaN         NaN
# 5          NaN         NaN         NaN         NaN         NaN         NaN
# 6          NaN         NaN         NaN         NaN         NaN         NaN
# 7          NaN         NaN         NaN         NaN         NaN         NaN
# 8          NaN         NaN         NaN         NaN         NaN         NaN
# 9          NaN         NaN         NaN         NaN         NaN         NaN
# 10         NaN         NaN         NaN         NaN         NaN         NaN
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ea62a8de-8936-4395-8828-1627174a723b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ea62a8de-8936-4395-8828-1627174a723b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
print(df.head())
# Out:
#    Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0         NaN        NaN        NaN        NaN
# 1         NaN        NaN        NaN        NaN
# 2         NaN        NaN        NaN        NaN
# 3         NaN        NaN        NaN        NaN
# 4         NaN        NaN        NaN        NaN

# %%
from google.colab import files
import pandas as pd

# Step 1: Upload the file
uploaded = files.upload()

# Step 2: Load the Excel file into a DataFrame
df = pd.read_excel('mashhod.xlsx')

# Step 3: Display the first few rows
print(df.head())
# Out:
#      <input type="file" id="files-b0e19e42-c4f0-4b96-a1a6-60fdc6df5dc3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b0e19e42-c4f0-4b96-a1a6-60fdc6df5dc3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# **DATA FRAMES**

# %%
dict2 = {
    "Students":["Saqlain","Noman","Ibrahim","Sudais","Haziq"],
    "Marks":[50,60,70,80,90],
    "City":["Karachi","Lahore","Islamabad","Peshawar","Quetta"],
    "Country":["Pakistan","Pakistan","Pakistan","Pakistan","Pakistan"],
    "Age":[20,21,22,23,2],
    "Gender":["Male","Male","Male","Male","Male"],
    "Status":["Single","Single","Single","Single","Single"],
    "Degree":["BS","BS","BS","BS","BS"],
    "University":["FAST","FAST","FAST","FAST","FAST"],
    "Salary":[50000,60000,70000,80000,90000],
    "Experience":[1,2,3,4,5],
    "Designation":["Software Engineer","Software Engineer","Software Engineer","Software Engineer","Software Engineer"],
    "Department":["IT","IT","IT","IT","IT"],
    "Salary Type":["Fixed","Fixed","Fixed","Fixed","Fixed"],
    "Salary Currency":["PKR","PKR","PKR","PKR","PKR"],
    "Salary Type":["Fixed","Fixed","Fixed","Fixed","Fixed"],
    "Salary Currency":["PKR","PKR","PKR","PKR","PKR"],
    "Salary Type":["Fixed","Fixed","Fixed","Fixed","Fixed"],
    "Salary Currency":["PKR","PKR","PKR","PKR","PKR"],
    "Salary Type":["Fixed","Fixed","Fixed","Fixed","Fixed"],
    "Salary Currency":["PKR","PKR","PKR","PKR","PKR"],
}
df =pd.DataFrame(dict2)

# %%
df
# Out:
#   Students  Marks       City   Country  Age Gender  Status Degree University  \
# 0  Saqlain     50    Karachi  Pakistan   20   Male  Single     BS       FAST
# 1    Noman     60     Lahore  Pakistan   21   Male  Single     BS       FAST
# 2  Ibrahim     70  Islamabad  Pakistan   22   Male  Single     BS       FAST
# 3   Sudais     80   Peshawar  Pakistan   23   Male  Single     BS       FAST
# 4    Haziq     90     Quetta  Pakistan    2   Male  Single     BS       FAST
#
#    Salary  Experience        Designation Department Salary Type  \
# 0   50000           1  Software Engineer         IT       Fixed
# 1   60000           2  Software Engineer         IT       Fixed
# 2   70000           3  Software Engineer         IT       Fixed
# 3   80000           4  Software Engineer         IT       Fixed
# 4   90000           5  Software Engineer         IT       Fixed
#
#   Salary Currency
# 0             PKR
# 1             PKR
# 2             PKR
# 3             PKR
# 4             PKR

# %%
df.head()
# Out:
#   Students  Marks       City   Country  Age Gender  Status Degree University  \
# 0  Saqlain     50    Karachi  Pakistan   20   Male  Single     BS       FAST
# 1    Noman     60     Lahore  Pakistan   21   Male  Single     BS       FAST
# 2  Ibrahim     70  Islamabad  Pakistan   22   Male  Single     BS       FAST
# 3   Sudais     80   Peshawar  Pakistan   23   Male  Single     BS       FAST
# 4    Haziq     90     Quetta  Pakistan    2   Male  Single     BS       FAST
#
#    Salary  Experience        Designation Department Salary Type  \
# 0   50000           1  Software Engineer         IT       Fixed
# 1   60000           2  Software Engineer         IT       Fixed
# 2   70000           3  Software Engineer         IT       Fixed
# 3   80000           4  Software Engineer         IT       Fixed
# 4   90000           5  Software Engineer         IT       Fixed
#
#   Salary Currency
# 0             PKR
# 1             PKR
# 2             PKR
# 3             PKR
# 4             PKR

# %%
df.tail()
# Out:
#   Students  Marks       City   Country  Age Gender  Status Degree University  \
# 0  Saqlain     50    Karachi  Pakistan   20   Male  Single     BS       FAST
# 1    Noman     60     Lahore  Pakistan   21   Male  Single     BS       FAST
# 2  Ibrahim     70  Islamabad  Pakistan   22   Male  Single     BS       FAST
# 3   Sudais     80   Peshawar  Pakistan   23   Male  Single     BS       FAST
# 4    Haziq     90     Quetta  Pakistan    2   Male  Single     BS       FAST
#
#    Salary  Experience        Designation Department Salary Type  \
# 0   50000           1  Software Engineer         IT       Fixed
# 1   60000           2  Software Engineer         IT       Fixed
# 2   70000           3  Software Engineer         IT       Fixed
# 3   80000           4  Software Engineer         IT       Fixed
# 4   90000           5  Software Engineer         IT       Fixed
#
#   Salary Currency
# 0             PKR
# 1             PKR
# 2             PKR
# 3             PKR
# 4             PKR

# %%
df.describe()
# Out:
#            Marks        Age        Salary  Experience
# count   5.000000   5.000000      5.000000    5.000000
# mean   70.000000  17.600000  70000.000000    3.000000
# std    15.811388   8.792042  15811.388301    1.581139
# min    50.000000   2.000000  50000.000000    1.000000
# 25%    60.000000  20.000000  60000.000000    2.000000
# 50%    70.000000  21.000000  70000.000000    3.000000
# 75%    80.000000  22.000000  80000.000000    4.000000
# max    90.000000  23.000000  90000.000000    5.000000

# %%
df.drop("Students",axis=1)
# Out:
#    Marks       City   Country  Age Gender  Status Degree University  Salary  \
# 0     50    Karachi  Pakistan   20   Male  Single     BS       FAST   50000
# 1     60     Lahore  Pakistan   21   Male  Single     BS       FAST   60000
# 2     70  Islamabad  Pakistan   22   Male  Single     BS       FAST   70000
# 3     80   Peshawar  Pakistan   23   Male  Single     BS       FAST   80000
# 4     90     Quetta  Pakistan    2   Male  Single     BS       FAST   90000
#
#    Experience        Designation Department Salary Type Salary Currency
# 0           1  Software Engineer         IT       Fixed             PKR
# 1           2  Software Engineer         IT       Fixed             PKR
# 2           3  Software Engineer         IT       Fixed             PKR
# 3           4  Software Engineer         IT       Fixed             PKR
# 4           5  Software Engineer         IT       Fixed             PKR

# %%
df
# Out:
#   Students  Marks       City   Country  Age Gender  Status Degree University  \
# 0  Saqlain     50    Karachi  Pakistan   20   Male  Single     BS       FAST
# 1    Noman     60     Lahore  Pakistan   21   Male  Single     BS       FAST
# 2  Ibrahim     70  Islamabad  Pakistan   22   Male  Single     BS       FAST
# 3   Sudais     80   Peshawar  Pakistan   23   Male  Single     BS       FAST
# 4    Haziq     90     Quetta  Pakistan    2   Male  Single     BS       FAST
#
#    Salary  Experience        Designation Department Salary Type  \
# 0   50000           1  Software Engineer         IT       Fixed
# 1   60000           2  Software Engineer         IT       Fixed
# 2   70000           3  Software Engineer         IT       Fixed
# 3   80000           4  Software Engineer         IT       Fixed
# 4   90000           5  Software Engineer         IT       Fixed
#
#   Salary Currency
# 0             PKR
# 1             PKR
# 2             PKR
# 3             PKR
# 4             PKR

# %%
df.drop(columns=["Students"],inplace=True)

# %%
df
# Out:
#    Marks       City   Country  Age Gender  Status Degree University  Salary  \
# 0     50    Karachi  Pakistan   20   Male  Single     BS       FAST   50000
# 1     60     Lahore  Pakistan   21   Male  Single     BS       FAST   60000
# 2     70  Islamabad  Pakistan   22   Male  Single     BS       FAST   70000
# 3     80   Peshawar  Pakistan   23   Male  Single     BS       FAST   80000
# 4     90     Quetta  Pakistan    2   Male  Single     BS       FAST   90000
#
#    Experience        Designation Department Salary Type Salary Currency
# 0           1  Software Engineer         IT       Fixed             PKR
# 1           2  Software Engineer         IT       Fixed             PKR
# 2           3  Software Engineer         IT       Fixed             PKR
# 3           4  Software Engineer         IT       Fixed             PKR
# 4           5  Software Engineer         IT       Fixed             PKR

# %%
df["Students"]= ["Saqlain","Noman","Ibrahim","Sudais","Haziq"]

# %%
df
# Out:
#    Marks       City   Country  Age Gender  Status Degree University  Salary  \
# 0     50    Karachi  Pakistan   20   Male  Single     BS       FAST   50000
# 1     60     Lahore  Pakistan   21   Male  Single     BS       FAST   60000
# 2     70  Islamabad  Pakistan   22   Male  Single     BS       FAST   70000
# 3     80   Peshawar  Pakistan   23   Male  Single     BS       FAST   80000
# 4     90     Quetta  Pakistan    2   Male  Single     BS       FAST   90000
#
#    Experience        Designation Department Salary Type Salary Currency  \
# 0           1  Software Engineer         IT       Fixed             PKR
# 1           2  Software Engineer         IT       Fixed             PKR
# 2           3  Software Engineer         IT       Fixed             PKR
# 3           4  Software Engineer         IT       Fixed             PKR
# 4           5  Software Engineer         IT       Fixed             PKR
#
#   Students
# 0  Saqlain
# 1    Noman
# 2  Ibrahim
# 3   Sudais
# 4    Haziq

# %%
df.to_csv("students.csv")

# %%
df = pd.read_excel('mashhod.xlsx')

# %%
df
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0          NaN         NaN         NaN         NaN         NaN         NaN
# 1          NaN         NaN         NaN         NaN         NaN         NaN
# 2          NaN         NaN         NaN         NaN         NaN         NaN
# 3          NaN         NaN         NaN         NaN         NaN         NaN
# 4          NaN         NaN         NaN         NaN         NaN         NaN
# 5          NaN         NaN         NaN         NaN         NaN         NaN
# 6          NaN         NaN         NaN         NaN         NaN         NaN
# 7          NaN         NaN         NaN         NaN         NaN         NaN
# 8          NaN         NaN         NaN         NaN         NaN         NaN
# 9          NaN         NaN         NaN         NaN         NaN         NaN
# 10         NaN         NaN         NaN         NaN         NaN         NaN
# ...

# %%
df.sort_index(axis=0,ascending=False)
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 23         NaN         NaN         NaN         NaN         NaN         NaN
# 22         NaN         NaN         NaN         NaN         NaN         NaN
# 21         NaN         NaN         NaN         NaN         NaN         NaN
# 20         NaN         NaN         NaN         NaN         NaN         NaN
# 19         NaN         NaN         NaN         NaN         NaN         NaN
# 18         NaN         NaN         NaN         NaN         NaN         NaN
# 17         NaN         NaN         NaN         NaN         NaN         NaN
# 16         NaN         NaN         NaN         NaN         NaN         NaN
# 15         NaN         NaN         NaN         NaN         NaN         NaN
# 14         NaN         NaN         NaN         NaN         NaN         NaN
# 13         NaN         NaN         NaN         NaN         NaN         NaN
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'],
#       dtype='object')

# %%
df.loc

# %%
df.iloc

# %%
df.duplicated(subset=["Unnamed: 6"])
# Out:
# 0     False
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# dtype: bool

# %%
df.drop_duplicates(subset=["Unnamed: 6"],keep="first")
# Out:
#    Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0         NaN        NaN        NaN        NaN

# %%
df.drop_duplicates(subset=["Unnamed: 6"],keep="last")
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 23         NaN         NaN         NaN         NaN         NaN         NaN
#
#     Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 23         NaN     Jacket   Clothing       6000
